# %%
import time

from discretize import TreeMesh, TensorMesh
from discretize.utils import refine_tree_xyz, active_from_xyz

from SimPEG.utils import mkvc, model_builder
from SimPEG import maps
import SimPEG.electromagnetics.time_domain as tdem

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from scipy import constants

try:
    from pymatsolver import Pardiso as Solver
except ImportError:
    from SimPEG import SolverLU as Solver


# %matplotlib widget

# %%
def peak_time(depth, conductivity, mu=constants.mu_0):
    """
    Compute peak time following TDEM diffussion formula
    """
    return 1 / 6 * mu * conductivity * depth**2

def peak_depth(time, conductivity, mu=constants.mu_0):
    """
    Compute peak depth following TDEM diffussion formula
    """
    return np.sqrt(2 * time / mu / conductivity)

def plotLoop(vertices, ax):
    """
    Plot loop
    """
    import matplotlib.pyplot as plt
    nVertices, nDim = np.shape(vertices)
    A=vertices[-1, :]
    for iSeg in range(nVertices):
        B=vertices[iSeg, :]
        ax.plot([A[0], B[0]], [A[1], B[1]], label=str(iSeg))
        A=B

# %% [markdown]
# Define survey
#
# 1 Trasmiter and 1 resivers in the center of the loop

# %%
# Trasmiter/source
source_width = 10 # Len of the cable in 1 side
source_location = np.array([
    [-source_width, -source_width, 0],
    [source_width, -source_width, 0],
    [source_width, source_width, 0],
    [-source_width, source_width, 0],
    [-source_width, -source_width, 0]
])

source_orientation = "z" 
source_current = 1.0  # maximum on-time current

# Define the source waveform. Define a unit step-off.
off_time = 1e-5
waveform = tdem.sources.StepOffWaveform(off_time)

# Observation times for response (time channels)
time_channels = np.logspace(-5, 1, 21)

# Define receiver list. They location is along the x-axis 
receiver_list = []
receiver_orientation = "z"  # "x", "y" or "z"
receiver_list.append(
    tdem.receivers.PointMagneticField(
        np.array([0, 0, 0]), time_channels, orientation=receiver_orientation
    )
)

# Define source list
source_list = [
    tdem.sources.LineCurrent(
        location = source_location,
        receiver_list=receiver_list,
        waveform=waveform,
        current=source_current,
    )
]

# Define the survey
survey = tdem.Survey(source_list)

# %% [markdown]
# Design mesh and simulation

# %%
# Conductivity in S/m (or resistivity in Ohm m)
air_conductivity = 1e-8
background_conductivity = 1e-1

# %%
min_simulation_time = off_time
max_simulation_time = 1e-0

# %% [markdown]
# Compute minimum and maximum diffusion distances

# %%
min_diffusion_distance = min(
    peak_depth(min_simulation_time, background_conductivity),
    peak_depth(min_simulation_time, air_conductivity),
) 

max_diffusion_distance = min(  # if I use the maximum I get crazy large values, I'll go with the min then
    peak_depth(max_simulation_time, background_conductivity),
    peak_depth(max_simulation_time, air_conductivity),
)

min_diffusion_distance, max_diffusion_distance
# Out:
# (12.615662606666971, 3989.4228029284545)

# %%
# Estimate smallest cell size as 10% of the smallest diffusion distance

smallest_cell_size = 0.1 * min_diffusion_distance
smallest_cell_size
# Out:
# 1.2615662606666973

# %%
cell_size = 2    # minimum cell size
n_cells_xz = 2**6
n_cells_y = 2**6

hxz = cell_size * np.ones(n_cells_xz)
hy = cell_size * np.ones(n_cells_y)

mesh = TreeMesh([hxz, hy, hxz],x0="CCC")

# Refine to largest possible cell size
mesh.refine(3, finalize=False)


# Define topography and refine 
[xx, yy] = np.meshgrid(mesh.nodes_x, mesh.nodes_y)
zz = 0 * np.ones_like(xx)
topo = np.c_[mkvc(xx), mkvc(yy), mkvc(zz)]

# Refine mesh
mesh.refine_surface(topo, -1, 
                    padding_cells_by_level=3, 
                    #pad_up=3, 
                    #pad_down=5
                   )
mesh.finalize()

# Set active cells and define unit values
ind_active = active_from_xyz(mesh, topo)
model_map = maps.InjectActiveCells(mesh, ind_active, air_conductivity)

# Define model for cells under the surface topography
model = background_conductivity * np.ones(ind_active.sum())

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ind_slice = int(mesh.h[1].size / 2)
mesh.plot_slice(model_map * model, normal='z', ax=ax, grid=True, ind=ind_slice)
ax.set_title(f"Model slice at z = {mesh.x0[1] + np.sum(mesh.h[1][0:ind_slice])} m ")
plotLoop(source_list[0].location, ax)
plt.plot(receiver_list[0].locations[0][0], 0* np.ones_like(receiver_list[0]), 'o')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ind_slice = int(mesh.h[1].size / 2)
mesh.plot_slice(model_map * model, normal='y', ax=ax, grid=True, ind=ind_slice)
ax.set_title(f"Model slice at y = {mesh.x0[1] + np.sum(mesh.h[1][0:ind_slice])} m ")
plt.plot(source_list[0].location[0][0], source_list[0].location[0][2], '*')
plt.plot(source_list[0].location[1][0], source_list[0].location[1][2], '*')
plt.plot(receiver_list[0].locations[0][0], 0* np.ones_like(receiver_list[0]), 'o')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mesh
# Out:
# OcTreeMesh: 11.82% filled
#
# Level : Number of cells               Mesh Extent               Cell Widths
# -----------------------           min     ,     max            min   ,   max
#   3   :       256            ---------------------------   --------------------
#   4   :      1024         x:     -64.0    ,    64.0           2.0    ,    16.0
#   5   :      5120         y:     -64.0    ,    64.0           2.0    ,    16.0
#   6   :      24576        z:     -64.0    ,    64.0           2.0    ,    16.0
# -----------------------
# Total :      30976

# %% [markdown]
# Simulation:

# %%
time_steps = [
            (1e-5, 10),
            (5e-5, 10),
            (1e-4, 10),
            (1e-3, 10),
            (5e-3, 10),
            (5e-2, 10),
            (1e-2, 10),
            (1e-1, 10),
            (1e-0, 9),
             ]

simulation = tdem.simulation.Simulation3DMagneticField(
    mesh, survey=survey, sigmaMap=model_map, solver=Solver
)

# Set the time-stepping for the simulation
simulation.time_steps = time_steps

# %%
# Logarithmic scale
# Create mesh with time steps
ts = TensorMesh([time_steps]).nodes_x


fig, ax = plt.subplots(figsize=(5, 5))
plt.title("Check time-steps on logarithmic-scale")
plt.plot([time_channels.min(), time_channels.min()], [-1, 1])
plt.plot([time_channels.max(), time_channels.max()], [-1, 1])

plt.plot(ts, ts * 0, ".", ms=10)
plt.plot(time_channels, time_channels*0, "x", ms=10)
plt.plot(off_time, off_time * 0, "*", ms=5)
plt.xscale("log")
plt.xlabel("Time (s)")
plt.show()

# Check times with time-steps
print(f"Min/max times    : {time_channels.min():.1e} / {time_channels.max():.1e}")
print(f"Min/max timeSteps: {ts[1]:.1e} / {ts[-1]:.1e}")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Min/max times    : 1.0e-05 / 1.0e+01
# Min/max timeSteps: 1.0e-05 / 1.1e+01

# %%
# Data are organized by transmitter, then by receiver then by observation time.
start = time.time()
dpred = simulation.dpred(model)
end = time.time()

print(f"Elapsed time: {end - start:.2f}s")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Data are organized by transmitter, then by receiver then by observation time.
#       2 start = time.time()
# ----> 3 dpred = simulation.dpred(model)
#       4 end = time.time()
#       6 print(f"Elapsed time: {end - start:.2f}s")
#
# File ~/.mambaforge/envs/simpeg-env/lib/python3.8/site-packages/SimPEG/simulation.py:448, in BaseTimeSimulation.dpred(self, m, f)
#     441     raise AttributeError(
#     442         "The survey has not yet been set and is required to compute "
#     443         "data. Please set the survey for the simulation: "
#     444         "simulation.survey = survey"
#     445     )
#     447 if f is None:
# --> 448     f = self.fields(m)
#     450 data = Data(self.survey)
#     451 for src in self.survey.source_list:
#
# File ~/.mambaforge/envs/simpeg-env/lib/python3.8/site-packages/SimPEG/electromagnetics/time_domain/simulation.py:93, in BaseTDEMSimulation.fields(self, m)
#      90 f = self.fieldsPair(self)
#      92 # set initial fields
# ---> 93 f[:, self._fieldType + "Solution", 0] = self.getInitialFields()
#      95 if self.verbose:
#      96     print("{}\nCalculating fields(m)\n{}".format("*" * 50, "*" * 50))
#
# File ~/.mambaforge/envs/simpeg-env/lib/python3.8/site-packages/SimPEG/electromagnetics/time_domain/simulation.py:432, in BaseTDEMSimulation.getInitialFields(self)
#     429     print("Calculating Initial fields")
#     431 for i, src in enumerate(Srcs):
# --> 432     ifields[:, i] = ifields[:, i] + getattr(
#     433         src, "{}Initial".format(self._fieldType), None
#     434     )(self)
#     436 return ifields
#
# File ~/.mambaforge/envs/simpeg-env/lib/python3.8/site-packages/SimPEG/electromagnetics/time_domain/sources.py:2033, in LineCurrent.hInitial(self, simulation)
#    2030 if self.waveform.has_initial_fields is False:
#    2031     return Zero()
# -> 2033 b = self.bInitial(simulation)
#    2034 return simulation.MeMuI * b
#
# File ~/.mambaforge/envs/simpeg-env/lib/python3.8/site-packages/SimPEG/electromagnetics/time_domain/sources.py:2082, in LineCurrent.bInitial(self, simulation)
#    2079 elif simulation._formulation != "HJ":
#    2080     raise NotImplementedError
# -> 2082 a = self._aInitial(simulation)
#    2083 return simulation.mesh.edge_curl.T * a
#
# File ~/.mambaforge/envs/simpeg-env/lib/python3.8/site-packages/SimPEG/electromagnetics/time_domain/sources.py:1998, in LineCurrent._aInitial(self, simulation)
#    1996 A = self._getAmmr(simulation)
#    1997 Ainv = simulation.solver(A)  # todo: store this
# -> 1998 s_e = self.s_e(simulation, 0)
#    1999 rhs = s_e + self.jInitial(simulation)
#    2000 return Ainv * rhs
#
# File ~/.mambaforge/envs/simpeg-env/lib/python3.8/site-packages/SimPEG/electromagnetics/time_domain/sources.py:2135, in LineCurrent.s_e(self, simulation, time)
#    2133     return self.Mejs(simulation) * self.waveform.eval(time)
#    2134 elif simulation._formulation == "HJ":
# -> 2135     return self.Mfjs(simulation) * self.waveform.eval(time)
#
# File ~/.mambaforge/envs/simpeg-env/lib/python3.8/site-packages/SimPEG/electromagnetics/time_domain/sources.py:1797, in LineCurrent.Mfjs(self, simulation)
#    1784 """Integrated electrical source term on faces
#    1785
#    1786 Parameters
#    (...)
#    1794     Contains the source term for all x, y, and z faces of the mesh.
#    1795 """
#    1796 if getattr(self, "_Mfjs", None) is None:
# -> 1797     self._Mfjs = line_through_faces(
#    1798         simulation.mesh, self.location, normalize_by_area=True
#    1799     )
#    1800 return self.current * self._Mfjs
#
# File ~/.mambaforge/envs/simpeg-env/lib/python3.8/site-packages/SimPEG/electromagnetics/utils/current_utils.py:416, in line_through_faces(mesh, locations, normalize_by_area, check_divergence, tolerance_divergence)
#     414 dimension = np.nonzero(np.abs(locations[i, :] - locations[i + 1, :]))[0]
#     415 if len(dimension) > 1:
# --> 416     not_aligned_error(i)
#     417 dimension = dimension[0]
#     418 direction = np.sign(locations[i, dimension] - locations[i + 1, dimension])
#
# File ~/.mambaforge/envs/simpeg-env/lib/python3.8/site-packages/SimPEG/electromagnetics/utils/current_utils.py:402, in line_through_faces.<locals>.not_aligned_error(i)
#     401 def not_aligned_error(i):
# --> 402     raise NotImplementedError(
#     403         "With the current implementation, the line between points "
#     404         "must align with the axes of the mesh. The points "
#     405         f"{locations[i, :]} and {locations[i+1, :]} do not."
#     406     )
#
# NotImplementedError: With the current implementation, the line between points must align with the axes of the mesh. The points [  9. -11.  -1.] and [11.  9. -1.] do not.

# %%
fig, ax = plt.subplots(figsize=(5, 5))

ax.plot(time_channels, dpred, lw=2, label=f'Station {0}')

ax.set_xscale('log')
ax.set_xlabel("Times (s)")
ax.set_ylabel('Hz [A/m]')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 fig, ax = plt.subplots(figsize=(5, 5))
# ----> 3 ax.plot(time_channels, dpred, lw=2, label=f'Station {0}')
#       5 ax.set_xscale('log')
#       6 ax.set_xlabel("Times (s)")
#
# NameError: name 'dpred' is not defined
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Theorical value for Bz [T]
constants.mu_0 * source_current / (2 * source_radius)
# Out:
# 6.283185310599999e-08

# %%
# Teorical value for Hz [A/m]
source_current / ( 2 * source_radius)
# Out:
# 0.05

# %%
# Value of time channel 0
dpred.max()
# Out:
# 0.04985918164086659

# %% [markdown]
# The value of the time channel 0 and the theorical value of Hz mast be equal.

# %%
# Compute the raduis of the loop according to the time channel 0 
1 / (dpred.max() * 2 / source_current)
# Out:
# 10.028243215090797

# %% [markdown]
# This value is similar to the used in the simulation.
